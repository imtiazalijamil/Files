# %% [markdown]
# ### 1. Import Libs

# %%
import smtplib
import openpyxl as xl
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from termcolor import colored
from random import randint
import time
from time import sleep
start_time = time.time()

# %% [markdown]
# #### TEXT Part

# %%
plain_txt = """

 
Meet the high-performance Navigation Stretch Down Jacket. 

  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌ ‌  ‌ ‌ ‌ ‌ 

 Enjoy free shipping and returns 

 

https://click.e.lululemon.com/?qs=d15457eb1fb374444b2650d35083c9fb48a59d6ceac5d0e024b22f87c866871cae4bf59e4893b1bf74106d95af8345807badeb68ec663586eabcf4949a3f1a9dSHOP WOMEN (https://click.e.lululemon.com/?qs=d15457eb1fb374442ea90a69ec6fa10150d21d528b5c78bd0f8c95672f15216ad476c2d992047e0665127a8a433b98cf2b6c539eaff40a6ad960cc5adf906556) |SHOP MEN (https://click.e.lululemon.com/?qs=d15457eb1fb3744490f7d784bcbb18d69c03f389aa2e4c3c9388438621fe6f64b3f554e299c4cd686d1d8d3fdf5355d7fb47659ae9d2ac0ddcfd321ca9fe727c) 

 

 https://click.e.lululemon.com/?qs=d15457eb1fb3744476801a91c4992029e36e98451708f6b9c776ba23984ab20479727d0fbb24eaf0c9295cc4fbf9d53158f4d6a06495579bc9b8c5dbd7a5ce54

  You work, you play, you sweat. Us? We design jackets that keep up with your busy life, all while keeping you looking good and protected from the elements.  

 SHOP WHAT'S NEW (https://click.e.lululemon.com/?qs=d15457eb1fb3744476801a91c4992029e36e98451708f6b9c776ba23984ab20479727d0fbb24eaf0c9295cc4fbf9d53158f4d6a06495579bc9b8c5dbd7a5ce54) 

  

https://click.e.lululemon.com/?qs=d15457eb1fb37444da714ccfb39a64797ebeca9a6dbe26a762fb0a607dfe402a305afd046fee3812779c5f7cb8d63985ea454093856b8572cac907b834a00642   

  Staying warm doesn't have to mean sacrificing style—not when it comes to the Navigation Stretch Down Jacket. Made with 700-fill-power goose-down insulation and a stylish cut, this is the kind of jacket that you'll find excuses to wear even when it's not cold out.  

 SHOP THE JACKET (https://click.e.lululemon.com/?qs=d15457eb1fb37444dccbdd3255bf750789dae415fcf62665e64b1f5275ad2a9211eeee855605fe61504f59327cf12ffb46c695c19c5a8bed738af38b8d0af9c3) 

  

https://click.e.lululemon.com/?qs=d15457eb1fb37444163fb24512557bce22e3f6ff8be53d7c3646d9c6d2a28300e5ef4a5ba9f45d47ec03d95b52996a6e15abd6b69dfd88e38016439ab9afc0d4   

  Bring it on, winter. Built with a cinchable hood for added protection on those chillier days and powered by ThermoChannel™ construction to lock in warmth, the Navigation Stretch Down Hoodie is ready for cold weather hangs.  

 SHOP THE HOODIE (https://click.e.lululemon.com/?qs=d15457eb1fb374447ff2cc22e10489f83cef867e68b1a3f0db71da3499a0606cce26a4a58a161d9ac04dd3a9312df5602382d37ceaaf56ad7d3649d45417787a) 

  

https://click.e.lululemon.com/?qs=d15457eb1fb37444d3a61296f124c7eb3018c0e6466305febc9555654bd3281d3c4d25cf8d14782b442b0b8403a52bafa0807c7342c01d2d9610021c1ac3e07b   

  When every day is a 'from-home' day, you deserve to be comfy. Our technical loungewear has four-way stretch for freedom of movement and is breathable, so you always feel good whether you're on a call, rolling out your mat, or taking it easy.  

 SHOP LOUNGEWEAR (https://click.e.lululemon.com/?qs=d15457eb1fb3744476f9203c6fec6767d5ffe98bd8d7cfa9107fba44fc8d37a1179c7ec0ec68a4607e584f5854646f1f11b3355f6ab4797989bc71a75f160a37) 

  

 Men's What's New 

https://click.e.lululemon.com/?qs=d15457eb1fb37444d9ab759d6c03242de009dad2f784b3ce08906b907e36011a308cb231836930e4a05c19d852539813a35aa8259a0527a05c8f989116e4c4c5

 

https://click.e.lululemon.com/?qs=d15457eb1fb3744476a9cb1fc360c36cd8e23fcdfd020ee8f1380ed49a780e1e16ad0f817b7737aa02495d045917a6e993ff1bcc652205dd8c7a866c3cfefc9bhttps://click.e.lululemon.com/?qs=d15457eb1fb374444babec3af1b286e5477286cf503a9a521ee490f9bb14dd11e8e3b503fdfc0781b77baf8e09945f972a008e1fb4b531f779f8ed76f02e20f9

 

https://click.e.lululemon.com/?qs=d15457eb1fb374448a7d0717026f49feda270d54d30e2d30296bcdcb51c4f5a5d91f2458b2cbdb651527190aa540bd8da04cd4f7d21890200bbec67dd405e8a5

 

https://click.e.lululemon.com/?qs=d15457eb1fb3744400c5c336f0faaea931d70a0d5440de7aff0e91c9ecf3e32d12b53c854e694ec10f410dc10185a586eed3f4fedd6f62f63c02b77a14c97011

 

https://click.e.lululemon.com/?qs=d15457eb1fb37444e24e8ab2dee6295d8c5ab28e775db8c818516cb3b5a16ed97ef0256222de41a7d6d45eaefe5b30c33b4428d4336bf09463fa5e1cae1fab22https://click.e.lululemon.com/?qs=d15457eb1fb37444b054d072e52f7717a05f60842a45853c563a6e523e52c276bb92e2a8b87c16cbff2f6f5e4dc6c944f0b6347d2151f85b94c971310dc8ea5f

 

https://click.e.lululemon.com/?qs=d15457eb1fb3744497e6e277814dc9eaf19f330c34aa093438b06d5e5d18cc2208d4a5f0f3d8c35ddafe8082e3af8a2a03e24c15ffeb9494959e090b81f22344

 

  

 SEE ALL (https://click.e.lululemon.com/?qs=d15457eb1fb37444950f54a5733ff215b39cec1eef5078b25918b2cf66151ce366b5a9217527febfa6a291aaaad1537b97d6d23703ffac5d222fa700e2ef5fb1) 

 

https://click.e.lululemon.com/?qs=d15457eb1fb374441748ca6745102579d1adb35c893e0fe367d77bb1f9d9bf61fdd159061afb3769ba4c927bc8e3b696afd14d349ac55782a46543ee9bc5e1bc

https://click.e.lululemon.com/?qs=d15457eb1fb374442cd6125a163f2be7d30e3ff0bb55d69cca30437b05931fe2d9bcec580e4f4cde7540c185f24338ae1184ea978356f03f8c58390e74b0b7d0

 More to Love 

 BRAS (https://click.e.lululemon.com/?qs=e4bf069a63a56ec040677a28fef4ae0c5e3801d362531bd4d25931bbab0e0a38d22e1eddad1128de4504760a10dc71bc4cdb99e607bcf1b2f24cd04500375fd1) 

 SHIRTS (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0fafed165d01695b1b22b9be55ebf86693c7672d59a2068640b780fec6f6c216390f0f6a2c5f41e1ea62b0f53fbe21e434a3639f36aec121a) 

 PANTS (https://click.e.lululemon.com/?qs=e4bf069a63a56ec00872fabe7f708df73b51b08840a0085d74c165f3b85dbac894b9f764d387346f61a4ae5761da04464465f26d8a64246d3abc89404322a8e5) 

 ACCESSORIES (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0be30816183a2d790b11d6d6a38e8007d7e57a513956e6b8cb7f1441abd9364106c3493ba83d10afcac12643a8c15b93d19716a225e962290) 

   

 https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f6339374ee252c4b51a1046a8369f6f03eec15987ec3c3b038b3b23a5ff73f6278a158339583ead1cf4fe6a40ab4ecbeb8e58eb0bc501a17 https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f8be1f0277ed1248de60f3c0d214ce4ec44bfb7a1ce17056733a456e77b423e9583aace94b353d87946e5b42a6ccc02b0bd0f255ace9100e  shop app (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f6339374ee252c4b51a1046a8369f6f03eec15987ec3c3b038b3b23a5ff73f6278a158339583ead1cf4fe6a40ab4ecbeb8e58eb0bc501a17) gift card (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f8be1f0277ed1248de60f3c0d214ce4ec44bfb7a1ce17056733a456e77b423e9583aace94b353d87946e5b42a6ccc02b0bd0f255ace9100e)  

 https://click.e.lululemon.com/?qs=e4bf069a63a56ec07f9c269f04fdf12bad1761420d71490390527334f797d2223a7936a3f57fb774b75c769f3075c9e57bbd3ad77e753e0545ef44c420e8be0e https://click.e.lululemon.com/?qs=e4bf069a63a56ec08942b7954a4840dd66865088337afdfeb8d1c09b07c3df52fffbbc2a8337b88dc2abdf748264b6a49c2a275140193a5a6f88a03308f62aa6  free shipping (https://click.e.lululemon.com/?qs=e4bf069a63a56ec07f9c269f04fdf12bad1761420d71490390527334f797d2223a7936a3f57fb774b75c769f3075c9e57bbd3ad77e753e0545ef44c420e8be0e) free returns (https://click.e.lululemon.com/?qs=e4bf069a63a56ec08942b7954a4840dd66865088337afdfeb8d1c09b07c3df52fffbbc2a8337b88dc2abdf748264b6a49c2a275140193a5a6f88a03308f62aa6)  

  

 SHOP WOMEN (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b45082c29657a02302790e557a6a2964ffae286ce9e08acf012af4954622d9879390e671c9e6c4e9c0bc7e404744de653888947af6041c17) |  SHOP MEN  (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0e382d16ee7add8866c53ef9ccbcbd77654a961c5ff5c4fe10f2887ef41389446b51a4eafad89773385d57155fd91bb58a31ea0785e05ba25) 

   

 https://click.e.lululemon.com/?qs=e4bf069a63a56ec09acc67e29ecee148d8c6f364e7633e7e6ec3962a1cb6f41971d6ef80c3b3585bf865af88b13c1cda875a3c7f3b76dea1a723a8389aee96ee https://click.e.lululemon.com/?qs=e4bf069a63a56ec03cfda6baba82fb86950c0fa5e3a5bdf2cb3bbd21486d0cce3a38c045d2b27b1966c3804af9a0d87cc5c581d06138a8cf4f92786531e97210 https://click.e.lululemon.com/?qs=e4bf069a63a56ec0fadd6306c10d3f0aeac9285afe86b29eacf7c598ab553ab84ce1cd239ba4c562fb33e8ae2c276c7ca74eb5f840c3d84163e44bbf0e4eee9f https://click.e.lululemon.com/?qs=e4bf069a63a56ec0944de42f67e76c2d60170eeff255dbfcea8c910e790b61342ed3ab0b8c4cd6686129515209101422f71c55d4edd4e9c3ad256f3cea0ad62b

 Question? Contact us. (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0523fcff525ec7a2967d8aa4a1ac6b41d27c9ef90f4820ca98d4b5da99f8f0eb9ac13193631178e1023775aec1182226b70456f5d2e5c0f5d) Privacy (https://click.e.lululemon.com/?qs=e4bf069a63a56ec06802e8cf75155be1a367c276caa77d0b609012357da429a6ed0c1f2d4b988661d47991a3610e8dea273803d5bce5f50a0039576966a50de6) | Terms (https://click.e.lululemon.com/?qs=e4bf069a63a56ec06f4aaa0f469e9ef54d506880ff26aec7ecc40d9dfc66b51b9ce3dd99c089e3dfd024c7854e529ca291e8cd4e2e7a7d986955468289eb9c11) | Careers (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0450ccb3a40027a75ab5f4ad39a50f0ebe28731a0e516c0880f3db545b61b3c4413bb1d3eb5d8301d8a3472bcdde3eaa69b92f7b69c92cbe9)   View in  web browser (https://view.e.lululemon.com/?qs=80ac8e571ad5621ceddf3f228936185173dd29d3ed241b6acf8267bb8230acec690d3b684d35abf616e8d1219db98301343198d07dbdbb9e06d4b2dbf5c3139ee85cbfce93cabfb0)   This version of the email was sent to ansarb24@gmail.com (mailto:ansarb24@gmail.com) 
Make sure this email goes to your inbox. Add hello@e.lululemon.com (mailto:hello@e.lululemon.com) to your address book. 
Already in the loop? Manage Preferences (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b2de9d74b15563ffed35c9ce74f4c432ebda7bbac613daf52d1084c267598b94ea60eecdb7caa1c311a8fd242404b8fa1d4add5aef5ab62d) or Unsubscribe (https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b2de9d74b15563ffed35c9ce74f4c432ebda7bbac613daf52d1084c267598b94ea60eecdb7caa1c311a8fd242404b8fa1d4add5aef5ab62d)   © 2020 LULULEMON ATHLETICA (https://click.e.lululemon.com/?qs=e4bf069a63a56ec057f800f491f205c2a85c75512458ad539cb95ed383041571bc0e08748a07838719f226d72ad2b5df1898868e8c060c9dd58f6100a6a69bb8) 1818 CORNWALL AVENUE, VANCOUVER BC, V6J 1C7 (https://click.e.lululemon.com/?qs=e4bf069a63a56ec057f800f491f205c2a85c75512458ad539cb95ed383041571bc0e08748a07838719f226d72ad2b5df1898868e8c060c9dd58f6100a6a69bb8)  

                                                            
"""

# %% [markdown]
# #### HTML Part

# %%
html_txt="""\


<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
<html>
  <head><META NAME="ROBOTS" CONTENT="NOINDEX, NOFOLLOW"><META NAME="referrer" CONTENT="no-referrer">
    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0" />
    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
    <meta name="x-apple-disable-message-reformatting">
    <style type="text/css">
      ReadMsgBody{ width: 100%;}
      .ExternalClass {width: 100%;}
      .ExternalClass, .ExternalClass p, .ExternalClass span, .ExternalClass font, .ExternalClass td, .ExternalClass div {line-height: 100%;}
      body {-webkit-text-size-adjust:100%; -ms-text-size-adjust:100%;margin:0 auto !important;}
      p { margin: 1em 0;}
      table td { border-collapse: collapse;}
      img {outline:0;}
      a img {border:none;}
      @-ms-viewport{ width: device-width;}
    </style>
    <style type="text/css">
      @media only screen and (max-width: 480px) {
        .container {width: 100% !important;}
        .footer { width:auto !important; margin-left:0; }
        .mobile-hidden { display:none !important; }
        .logo { display:block !important; padding:0 !important; }
        img { max-width:100% !important; height:auto !important; max-height:auto !important;}
        .header img{max-width:100% !important;height:auto !important; max-height:auto !important;}
        .photo img { width:100% !important; max-width:100% !important; height:auto !important;}
        .drop { display:block !important; width: 100% !important; float:left; clear:both;}
        .footerlogo { display:block !important; width: 100% !important; padding-top:15px; float:left; clear:both;}
        .nav4, .nav5, .nav6 { display: none !important; }
        .tableBlock {width:100% !important;}
        .responsive-td {width:100% !important; display:block !important; padding:0 !important; }
        .fluid, .fluid-centered {
          width: 100% !important;
          max-width: 100% !important;
          height: auto !important;
          margin-left: auto !important;
          margin-right: auto !important;
        }
        .fluid-centered {
          margin-left: auto !important;
          margin-right: auto !important;
        }
        /* MOBILE GLOBAL STYLES - DO NOT CHANGE */
        body { padding: 0px !important; font-size: 16px !important; line-height: 150% !important;}
        h1 { font-size: 22px !important; line-height: normal !important;}
        h2 { font-size: 20px !important; line-height: normal !important;}
        h3 { font-size: 18px !important; line-height: normal !important;}
        .buttonstyles {
          font-family:arial,helvetica,sans-serif !important;
          font-size: 16px !important;
          color: #FFFFFF !important;
          padding: 10px !important;
        }
        /* END OF MOBILE GLOBAL STYLES - DO NOT CHANGE */
      }
      @media only screen and (max-width: 640px) {
        .container { width:100% !important; }
        .mobile-hidden { display:none !important; }
        .logo { display:block !important; padding:0 !important; }
        .photo img { width:100% !important; height:auto !important;}
        .nav5, .nav6 { display: none !important;}
        .fluid, .fluid-centered {
          width: 100% !important;
          max-width: 100% !important;
          height: auto !important;
          margin-left: auto !important;
          margin-right: auto !important;
        }
        .fluid-centered {
          margin-left: auto !important;
          margin-right: auto !important;
        }
      }
    </style>
    <!--[if mso]>       <style type="text/css">           /* Begin Outlook Font Fix */           body, table, td {               font-family: Arial, Helvetica, sans-serif ;               font-size:16px;               color:#000000;               line-height:1;           }       </style>     <![endif]-->
    
        <!-- START - from Responsys -->
    <style type="text/css">
#outlook a{padding:0}table{mso-table-lspace:0;mso-table-rspace:0}.ReadMsgBody{width:100%}.ExternalClass{width:100%}.ExternalClass,.ExternalClass div,.ExternalClass font,.ExternalClass p,.ExternalClass span,.ExternalClass td{line-height:100%}a,td{mso-line-height-rule:exactly}a[href^=sms],a[href^=tel]{color:inherit;cursor:default;text-decoration:none}a,body,table,td{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}a img{border:none}img{outline:0;text-decoration:none;border:none;-ms-interpolation-mode:bicubic}a[x-apple-data-detectors]{color:inherit!important;text-decoration:none!important;font-size:inherit!important;font-family:inherit!important;font-weight:inherit!important;line-height:inherit!important}img{-ms-interpolation-mode:bicubic}#outlook
 a{padding:0}.ReadMsgBody{width:100%}.ExternalClass{width:100%}a,p,td{mso-line-height-rule:exactly}a,body,p,table,td{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}.ExternalClass,.ExternalClass div,.ExternalClass font,.ExternalClass p,.ExternalClass span,.ExternalClass td{line-height:100%}#MessageViewBody a{color:inherit;text-decoration:none;font-size:inherit;font-family:inherit;font-weight:inherit;line-height:inherit}a[x-apple-data-detectors]{color:inherit!important;text-decoration:none!important;font-size:inherit!important;font-family:inherit!important;font-weight:inherit!important;line-height:inherit!important}span.MsoHyperlink{mso-style-priority:99;color:inherit}span.MsoHyperlinkFollowed{mso-style-priority:99;color:inherit}
</style>
<style>
body{height:100%!important;margin:0!important;padding:0!important;width:100%!important;background-color:#fff}table{border-spacing:0;font-family:sans-serif;color:#333}td{padding:0}img{border:0}.wrapper{width:100%;table-layout:fixed;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.webkit{max-width:620px;margin:0 auto}.outer{Margin:0 auto;width:100%;max-width:620px}.full-width-image img{width:100%;max-width:620px;height:auto}.inner{padding:0}.one-column .contents{text-align:left}.two-column{text-align:center;font-size:0}.two-column .column{width:100%;max-width:300px;display:inline-block;vertical-align:top}.contents{width:100%}.two-column img{width:100%;max-width:300px;height:auto}.three-column{text-align:center;font-size:0;padding-top:10px;padding-bottom:10px}.three-column
 .column{width:100%;max-width:210px;display:inline-block;vertical-align:top}.three-column img{width:100%;max-width:210px;height:auto}.three-column .text{padding-top:10px}.left-sidebar{text-align:center;font-size:0}.left-sidebar .column{width:100%;display:inline-block;vertical-align:middle}.left-sidebar .left{max-width:300px}.left-sidebar .right{max-width:300px}.left-sidebar .img{width:100%;max-width:300px;height:auto}.left-sidebar .contents{font-size:12px;text-align:center}.left-sidebar a{color:#85ab70}.right-sidebar{text-align:center;font-size:0}.right-sidebar .column{width:100%;display:inline-block;vertical-align:middle}.right-sidebar .left{max-width:300px}.right-sidebar .right{max-width:300px}.right-sidebar .img{width:100%;max-width:300px;height:auto}.right-sidebar
 .contents{font-size:12px;text-align:center}.right-sidebar a{color:#70bbd9}
</style>
<style type="text/css">

@media screen and (-webkit-min-device-pixel-ratio:0) {
.webkit-hide {
display: none !important
}
.webkit-show {
display: block !important;
max-height: none !important
}
}
</style>
    <style>
@media screen and (max-width: 590px) {
bobody[yahoo] .hide, span[class="hide"], td[class="hide"], img[class="hide"] {
display: none!important;
}
      }
    </style>
    <style type="text/css">

@media screen and (min-width: 401px) and (max-width: 620px) {
.two-column .column, .two-column img {
max-width: 100% !important;
}
.three-column .column, .three-column img, .six-column .column {
max-width: 50% !important;
}
.three-column .column {
max-width: 33% !important;
}
.two-column .column {
max-width: 50% !important;
}
}
@media screen and (max-width: 480px) {
.two-column .column, .two-column img {
max-width: 100% !important;
}
.three-column .column, .three-column img, .six-column .column {
max-width: 50% !important;
}
.full {
width: 100% !important;
max-width: none !important;
}
  .mbl-mtl-padding {
    padding-right:10px !important;
    padding-left:10px !important;
  }
}
</style>
<style type="text/css">

@media screen {
@font-face {
font-family: 'CalibreWeb-Thin';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Thin.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Regular';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Regular.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Semibold';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Semibold.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Medium';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Medium.woff) format('woff');
}
@font-face{
font-family:'Verlag-Book';
src: url(https://globalstaticassets.lululemon.com/fonts/A8ED03B0C127F2F16.woff2) format('woff');
}
@font-face{
font-family:'Verlag-Bold';
src: url(https://globalstaticassets.lululemon.com/fonts/7D48ED1EE5064DD52.woff) format('woff');
}
}
</style>
<style>
@media screen and (max-width: 590px) {
  .free-shipping-header {
   padding: 7px 15px 7px 10px !important;
  }
  
  .header-row2 {
   padding-left: 15px !important;
   padding-right: 15px !important; 
  }
}
</style>
<style>
.image-desktop {display:block !important; max-width:620px !important;}
.image-mobile {display:none !important; max-width:480px !important;}
  
@media screen and (max-width: 590px) {
.image-desktop {display:none !important; max-width:620px !important;}
  
  .image-mobile {display:block !important; max-width:480px !important;}
}
</style>
<style>
.two-up-image-desktop {display:inline-block !important;}
.two-up-table-row-desktop {display:table-row !important;}
.two-up-image-mobile {display:none !important; }
  .height-two-up {
    height:372px;
  }
  
@media screen and (max-width: 590px) {
.two-up-image-desktop {display:none !important;}
  .two-up-table-row-desktop {display:none !important;}
  .two-up-image-mobile {display:inline-block !important;}
  .height-two-up {
  height:auto;
  }
}
</style>
    <style>
.gmailfix {
 display:none;
 display:none!important;
}
</style>
    <!-- END - from Responsys -->
  </head>
  <body bgcolor="#ffffff" text="#000000" style="background-color: #ffffff; color: #000000; padding: 0px; -webkit-text-size-adjust:none; font-size: 16px; font-family:arial,helvetica,sans-serif;"><style type="text/css">
div.preheader 
{ display: none !important; } 
</style>
<div class="preheader" style="font-size: 1px; display: none !important;">Meet the high-performance Navigation Stretch Down Jacket.</div>
    <style type="text/css">
      ReadMsgBody{ width: 100%;}
      .ExternalClass {width: 100%;}
      .ExternalClass, .ExternalClass p, .ExternalClass span, .ExternalClass font, .ExternalClass td, .ExternalClass div {line-height: 100%;}
      body {-webkit-text-size-adjust:100%; -ms-text-size-adjust:100%;margin:0 auto !important;}
      p { margin: 1em 0;}
      table td { border-collapse: collapse;}
      img {outline:0;}
      a img {border:none;}
      @-ms-viewport{ width: device-width;}
    </style>
    <style type="text/css">
      @media only screen and (max-width: 480px) {
        .container {width: 100% !important;}
        .footer { width:auto !important; margin-left:0; }
        .mobile-hidden { display:none !important; }
        .logo { display:block !important; padding:0 !important; }
        img { max-width:100% !important; height:auto !important; max-height:auto !important;}
        .header img{max-width:100% !important;height:auto !important; max-height:auto !important;}
        .photo img { width:100% !important; max-width:100% !important; height:auto !important;}
        .drop { display:block !important; width: 100% !important; float:left; clear:both;}
        .footerlogo { display:block !important; width: 100% !important; padding-top:15px; float:left; clear:both;}
        .nav4, .nav5, .nav6 { display: none !important; }
        .tableBlock {width:100% !important;}
        .responsive-td {width:100% !important; display:block !important; padding:0 !important; }
        .fluid, .fluid-centered {
          width: 100% !important;
          max-width: 100% !important;
          height: auto !important;
          margin-left: auto !important;
          margin-right: auto !important;
        }
        .fluid-centered {
          margin-left: auto !important;
          margin-right: auto !important;
        }
        /* MOBILE GLOBAL STYLES - DO NOT CHANGE */
        body { padding: 0px !important; font-size: 16px !important; line-height: 150% !important;}
        h1 { font-size: 22px !important; line-height: normal !important;}
        h2 { font-size: 20px !important; line-height: normal !important;}
        h3 { font-size: 18px !important; line-height: normal !important;}
        .buttonstyles {
          font-family:arial,helvetica,sans-serif !important;
          font-size: 16px !important;
          color: #FFFFFF !important;
          padding: 10px !important;
        }
        /* END OF MOBILE GLOBAL STYLES - DO NOT CHANGE */
      }
      @media only screen and (max-width: 640px) {
        .container { width:100% !important; }
        .mobile-hidden { display:none !important; }
        .logo { display:block !important; padding:0 !important; }
        .photo img { width:100% !important; height:auto !important;}
        .nav5, .nav6 { display: none !important;}
        .fluid, .fluid-centered {
          width: 100% !important;
          max-width: 100% !important;
          height: auto !important;
          margin-left: auto !important;
          margin-right: auto !important;
        }
        .fluid-centered {
          margin-left: auto !important;
          margin-right: auto !important;
        }
      }
    </style>
    <!--[if mso]>       <style type="text/css">           /* Begin Outlook Font Fix */           body, table, td {               font-family: Arial, Helvetica, sans-serif ;               font-size:16px;               color:#000000;               line-height:1;           }           /* End Outlook Font Fix */       </style>     <![endif]-->
    
        <!-- START - from Responsys -->
    <style type="text/css">
#outlook a{padding:0}table{mso-table-lspace:0;mso-table-rspace:0}.ReadMsgBody{width:100%}.ExternalClass{width:100%}.ExternalClass,.ExternalClass div,.ExternalClass font,.ExternalClass p,.ExternalClass span,.ExternalClass td{line-height:100%}a,td{mso-line-height-rule:exactly}a[href^=sms],a[href^=tel]{color:inherit;cursor:default;text-decoration:none}a,body,table,td{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}a img{border:none}img{outline:0;text-decoration:none;border:none;-ms-interpolation-mode:bicubic}a[x-apple-data-detectors]{color:inherit!important;text-decoration:none!important;font-size:inherit!important;font-family:inherit!important;font-weight:inherit!important;line-height:inherit!important}img{-ms-interpolation-mode:bicubic}#outlook
 a{padding:0}.ReadMsgBody{width:100%}.ExternalClass{width:100%}a,p,td{mso-line-height-rule:exactly}a,body,p,table,td{-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}.ExternalClass,.ExternalClass div,.ExternalClass font,.ExternalClass p,.ExternalClass span,.ExternalClass td{line-height:100%}#MessageViewBody
 a{color:inherit;text-decoration:none;font-size:inherit;font-family:inherit;font-weight:inherit;line-height:inherit}a[x-apple-data-detectors]{color:inherit!important;text-decoration:none!important;font-size:inherit!important;font-family:inherit!important;font-weight:inherit!important;line-height:inherit!important}span.MsoHyperlink{mso-style-priority:99;color:inherit}span.MsoHyperlinkFollowed{mso-style-priority:99;color:inherit}table{border-spacing:0;font-family:sans-serif;color:#333}td{padding:0}img{border:0}.wrapper{width:100%;table-layout:fixed;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}.webkit{max-width:620px;margin:0 auto}.outer{Margin:0 auto;width:100%;max-width:620px}.full-width-image img{width:100%;max-width:620px;height:auto}.inner{padding:0}.one-column
 .contents{text-align:left}.two-column{text-align:center;font-size:0}.two-column .column{width:100%;max-width:300px;display:inline-block;vertical-align:top}.contents{width:100%}.two-column img{width:100%;max-width:300px;height:auto}.three-column{text-align:center;font-size:0;padding-top:10px;padding-bottom:10px}.three-column .column{width:100%;max-width:210px;display:inline-block;vertical-align:top}.three-column img{width:100%;max-width:210px;height:auto}.three-column .text{padding-top:10px}.left-sidebar{text-align:center;font-size:0}.left-sidebar .column{width:100%;display:inline-block;vertical-align:middle}.left-sidebar .left{max-width:300px}.left-sidebar .right{max-width:300px}.left-sidebar .img{width:100%;max-width:300px;height:auto}.left-sidebar
 .contents{font-size:12px;text-align:center}.left-sidebar a{color:#85ab70}.right-sidebar{text-align:center;font-size:0}.right-sidebar .column{width:100%;display:inline-block;vertical-align:middle}.right-sidebar .left{max-width:300px}.right-sidebar .right{max-width:300px}.right-sidebar .img{width:100%;max-width:300px;height:auto}.right-sidebar .contents{font-size:12px;text-align:center}.right-sidebar a{color:#70bbd9}.webkit-show{display:block!important;max-height:none!important}
</style>
    <style>
@media screen and (max-width: 590px) {
bobody[yahoo] .hide, span[class="hide"], td[class="hide"], img[class="hide"] {
display: none!important;
}
      }
    </style>
    <style type="text/css">

@media screen and (min-width: 401px) and (max-width: 620px) {
.two-column .column, .two-column img {
max-width: 100% !important;
}
.three-column .column, .three-column img, .six-column .column {
max-width: 50% !important;
}
.three-column .column {
max-width: 33% !important;
}
.two-column .column {
max-width: 50% !important;
}
}
@media screen and (max-width: 480px) {
.two-column .column, .two-column img {
max-width: 100% !important;
}
.three-column .column, .three-column img, .six-column .column {
max-width: 50% !important;
}
.full {
width: 100% !important;
max-width: none !important;
}
  .mbl-mtl-padding {
    padding-right:10px !important;
    padding-left:10px !important;
  }
}
</style>
<style type="text/css">

@media screen {
@font-face {
font-family: 'CalibreWeb-Thin';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Thin.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Regular';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Regular.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Semibold';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Semibold.woff) format('woff');
}
@font-face {
font-family: 'CalibreWeb-Medium';
font-style: normal;
font-weight: normal;
src: url(https://globalstaticassets.lululemon.com/fonts/CalibreWeb-Medium.woff) format('woff');
}
@font-face{
font-family:'Verlag-Book';
src: url(https://globalstaticassets.lululemon.com/fonts/A8ED03B0C127F2F16.woff2) format('woff');
}
@font-face{
font-family:'Verlag-Bold';
src: url(https://globalstaticassets.lululemon.com/fonts/7D48ED1EE5064DD52.woff) format('woff');
}
}
</style>
<style>
@media screen and (max-width: 590px) {
  .free-shipping-header {
   padding: 7px 15px 7px 10px !important;
  }
  
  .header-row2 {
   padding-left: 15px !important;
   padding-right: 15px !important; 
  }
}
</style>
<style>
.image-desktop {display:block !important; max-width:620px !important;}
.image-mobile {display:none !important; max-width:480px !important;}
  
@media screen and (max-width: 590px) {
.image-desktop {display:none !important; max-width:620px !important;}
  
  .image-mobile {display:block !important; max-width:480px !important;}
}
</style>
<style>
.two-up-image-desktop {display:inline-block !important;}
.two-up-image-mobile {display:none !important; }
  .height-two-up {
  height:372px;
  }
  
@media screen and (max-width: 590px) {
.two-up-image-desktop {display:none !important;}
  
  .two-up-image-mobile {display:inline-block !important;}
  .height-two-up {
  height:auto;
  }
}
</style>
    <!-- END - from Responsys -->
    <div style="font-size:0; line-height:0;"><img src="https://click.e.lululemon.com/open.aspx?ffcb10-ff2a1c71716c-fe6517767667017d7411-fe38117171640478741675-ff931779-fe6015717362047b7c16-ff2d10797165&d=110005" alt="" width="1" height="1"></div>
    <table width="100%" border="0" cellpadding="0" cellspacing="0" align="center">
      <tr>
        <td align="center" valign="top">
          
          <div style="display: none; max-height: 0px; overflow: hidden;"> </div>
<!-- Insert &zwnj;&nbsp; hack after hidden preview text -->
<div style="display: none; max-height: 0px; overflow: hidden;">
 &nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;
&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;
&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;
&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj;&nbsp;&zwnj; </div>
        </td>
      </tr>
      <tr>
        <td align="center">
          <table cellspacing="0" cellpadding="0" border="0" width="620" class="container" align="center">
            <tr>
              <td>
                <table class="tb_properties border_style" style="background-color:#FFFFFF;" cellspacing="0" cellpadding="0" bgcolor="#ffffff" width="100%">
                  <tr>
                    <td align="center" valign="top">
                      <table align="left" border="0" cellpadding="0" cellspacing="0" width="100%">
                        <tr>
                          <!-- added padding here -->
                          <td class="content_padding" style="">
                            <!-- end of comment -->
                            <table border="0" cellpadding="0" cellspacing="0" width="100%">
                              <tr> <!-- top slot -->
                                <td align="center" class="header" valign="top">
                                  <table align="left" border="0" cellpadding="0" cellspacing="0" width="100%">
                                    <tbody>
                                        <tr>
                                          <td align="left" valign="top">
                                            <table cellspacing="0" cellpadding="0" style="width:100%">
                                              <tbody>
                                              <tr>
                                                <td class="responsive-td" valign="top" style="width: 100%;">
                                                  <!---->
<div style="display:none;">
</div>
<table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;"><tr><td align="center" border="0" cellpadding="0" cellspacing="0" class="w100" style="max-width:620px;width:100%;" valign="middle"><!--[if (gte mso 9)|(IE)]><table style="width:620px;" align="center" cellpadding="0" cellspacing="0" border="0"><tr> <![endif]--><table align="center" bgcolor="#f1f1f1" border="0" cellpadding="0" cellspacing="0" style="width:100%;background-color:#F7F7F7;max-width:620px;height:40px;"><tr> 
<td class="free-shipping-header" style="padding:7px 30px 7px 10px; color:#57585B; font-size:14px; line-height:17px; font-family: 'CalibreWeb-Regular', helvetica, arial, sans-serif; text-align:right;letter-spacing:1px;white-space:nowrap !important;-webkit-text-size-adjust:none; text-size-adjust:none;">Enjoy free shipping and returns</td></tr> </table> <!--[if (gte mso 9)|(IE)]></table></tr> <![endif]--></td></tr><tr><td class="one-column header-row2" style="padding-left: 30px; padding-right: 30px;" align="center"><!--[if true]><table width="100%" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="100%"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 620px; width: 100%;"><tr><td width="20" height="20" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td align="center" valign="top">
<table border="0" cellpadding="5" cellspacing="0" width="100%"><tr><td align="left" valign="top"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb374444b2650d35083c9fb48a59d6ceac5d0e024b22f87c866871cae4bf59e4893b1bf74106d95af8345807badeb68ec663586eabcf4949a3f1a9d">
<img alt="lululemon athletica" border="0" height="30" src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/da0d9878-b620-4533-bae3-813392f665b4.png" style="font-family: 'Verlag-Book', helvetica, arial, sans-serif; color: #000000; font-size: 14px; text-decoration: none; text-align:center;" width="30"> </a></td><td align="right" style="width:150px;padding-right:12px;text-align:right;white-space:nowrap !important;"><a class="nav-header" href="https://click.e.lululemon.com/?qs=d15457eb1fb374442ea90a69ec6fa10150d21d528b5c78bd0f8c95672f15216ad476c2d992047e0665127a8a433b98cf2b6c539eaff40a6ad960cc5adf906556" style="font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 13px; letter-spacing: 1px; text-decoration:none;font-weight: normal;color:#000000; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;-webkit-text-size-adjust:none; text-size-adjust:none;">
<span style="color:#000000;">SHOP&nbsp;WOMEN</span></a></td><td align="center" class="nav-header" style="font-family: 'Verlag-Bold', helvetica, arial, sans-serif; font-size:13px;letter-spacing:1em;text-decoration:none;color:#dfdfdf !important;width:20px; text-align:center;-webkit-text-size-adjust:none; text-size-adjust:none;"><span style="color:#000000;">|</span></td><td align="right" class="nav-mens" style="width:1%;white-space:nowrap !important; text-align:right;">
<a class="nav-header" href="https://click.e.lululemon.com/?qs=d15457eb1fb3744490f7d784bcbb18d69c03f389aa2e4c3c9388438621fe6f64b3f554e299c4cd686d1d8d3fdf5355d7fb47659ae9d2ac0ddcfd321ca9fe727c" style="font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 13px; letter-spacing: 1px; font-weight: normal;text-decoration:none;color:#000000; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;-webkit-text-size-adjust:none; text-size-adjust:none;"><span style="color:#000000;">SHOP&nbsp;MEN</span></a></td></tr></table></td></tr><tr><td width="20" height="20" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr></table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1"><tr><td class="one-column" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;" align="center"><table align="center" border="0" cellpadding="0" cellspacing="0" width="100%"><tr><td align="center" style="padding-top:0px; padding-left:0px; padding-bottom:0px; padding-right: 0px;">  </a> <a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744476801a91c4992029e36e98451708f6b9c776ba23984ab20479727d0fbb24eaf0c9295cc4fbf9d53158f4d6a06495579bc9b8c5dbd7a5ce54">  
<img alt="Beyond a winter jacket. - SHOP WHAT'S NEW" class="image-desktop" border="0" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Email_Hero" style="border: 0; display: block; color: #333333; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: normal; height: auto; max-width: 620px; outline: 0; padding: 0; width: 100%;" width="620"> <!--[if !mso]> <!--> <img alt="Beyond a winter jacket. - SHOP WHAT'S NEW" class="image-mobile" border="0" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Email_Hero" style="border: 0; display: none; color: #333333; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: normal; height: auto; max-width: 620px; outline: 0; padding: 0; width: 100%;" width="620"> <!-- <![endif]--> </a></td></tr></table></td></tr> <tr>
<td class="one-column" style="padding-top:0;padding-bottom:0;padding-right:15px;padding-left:15px;" bgcolor="#E1E1E1" align="center"> <!--[if true]><table width="400" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="400"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 400px; width: 100%;"> <tr><td width="30" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="color: #000000; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 20px; line-height: 24px; text-align: center; font-weight: normal; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">You work, you play, you sweat. Us? We design jackets that keep up with your busy life, all while keeping you looking good and protected from the elements.</td></tr>  <tr>
<td width="15" height="30" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="border-collapse:collapse" align="center"><table align="center" style="border-collapse:collapse; margin:0 auto;padding:0; border-spacing:0; background-color:#FFFFFF" cellpadding="0" cellspacing="0" border="0"><tr><td style="border-collapse:collapse; padding:0; border: 1px solid #000000; text-align:center; mso-padding-alt:15px 40px; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 14px; color:#ffffff; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" align="center">  </a> 
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744476801a91c4992029e36e98451708f6b9c776ba23984ab20479727d0fbb24eaf0c9295cc4fbf9d53158f4d6a06495579bc9b8c5dbd7a5ce54" target="_blank" style="text-decoration:none; line-height:18px; text-align:center; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#000000; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;">  <span style="padding:12.5px 20.5px;display:block">SHOP WHAT'S NEW</span> </a></td></tr></table></td></tr> <tr><td width="30" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr> </table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1" width="100%"><tr style="display:block;"><td align="center" class="full-width-image" style="border:0;display:inline-block;padding-top:15px;padding-bottom:0px;padding-right:15px;padding-left:15px;"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444da714ccfb39a64797ebeca9a6dbe26a762fb0a607dfe402a305afd046fee3812779c5f7cb8d63985ea454093856b8572cac907b834a00642" style="text-decoration: none"> 
<img alt="SHOP THE JACKET" class="image-desktop" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Hero_Support_1UP_D_TheJacket" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;" width="100%"> <!--[if !mso]><!--> <img alt="SHOP THE JACKET" class="image-mobile" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Hero_Support_1UP_M_TheJacket" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;display:none;" width="100%"> 
<!-- <![endif]--> </a></td></tr> <tr><td width="10" height="15" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> </table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1"><tr><td class="one-column" style="border:0;padding-top:0;padding-bottom:0;padding-right:15px;padding-left:15px;" bgcolor="#E1E1E1" align="center"> <!--[if true]><table width="400" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" border="0" width="400"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="border:0;margin: 0 auto; max-width: 590px; width: 100%;"><tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>  <tr>
<td style="border:0;padding:0px 31px 0px 31px;color: #000000; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 20px; line-height: 24px; text-align: center; font-weight: normal; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">Staying warm doesn't have to mean sacrificing style—not when it comes to the Navigation Stretch Down Jacket. Made with 700-fill-power goose-down insulation and a stylish cut, this is the kind of jacket that you'll find excuses to wear even when it's not cold out.</td></tr>  <tr><td width="15" height="30" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="border-collapse:collapse" align="center"><table align="center" style="border:0;border-collapse:collapse; margin:0 auto;padding:0; border-spacing:0; background-color:#FFFFFF" cellpadding="0" cellspacing="0" border="0"><tr>
<td style="border:0;border-collapse:collapse; padding:0; border: 1px solid #000000; text-align:center; mso-padding-alt:15px 40px; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#ffffff; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444dccbdd3255bf750789dae415fcf62665e64b1f5275ad2a9211eeee855605fe61504f59327cf12ffb46c695c19c5a8bed738af38b8d0af9c3" target="_blank" style="text-decoration:none; line-height:18px; text-align:center; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#000000; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;"> <span style="padding:12.5px 20.5px;display:block">SHOP THE JACKET</span> </a></td></tr></table></td></tr> <tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr></table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1" width="100%"><tr style="display:block;"><td align="center" class="full-width-image" style="border:0;display:inline-block;padding-top:15px;padding-bottom:0px;padding-right:15px;padding-left:15px;"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444163fb24512557bce22e3f6ff8be53d7c3646d9c6d2a28300e5ef4a5ba9f45d47ec03d95b52996a6e15abd6b69dfd88e38016439ab9afc0d4" style="text-decoration: none"> 
<img alt="SHOP THE HOODIE" class="image-desktop" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Hero_Support_1UP_D_TheHoodie" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;" width="100%"> <!--[if !mso]><!--> <img alt="SHOP THE HOODIE" class="image-mobile" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_Hero_Support_1UP_M_TheHoodie" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;display:none;" width="100%"> 
<!-- <![endif]--> </a></td></tr> <tr><td width="10" height="15" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> </table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1"><tr><td class="one-column" style="border:0;padding-top:0;padding-bottom:0;padding-right:15px;padding-left:15px;" bgcolor="#E1E1E1" align="center"> <!--[if true]><table width="400" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" border="0" width="400"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="border:0;margin: 0 auto; max-width: 590px; width: 100%;"><tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>  <tr>
<td style="border:0;padding:0px 31px 0px 31px;color: #000000; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 20px; line-height: 24px; text-align: center; font-weight: normal; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">Bring it on, winter. Built with a cinchable hood for added protection on those chillier days and powered by ThermoChannel™ construction to lock in warmth, the Navigation Stretch Down Hoodie is ready for cold weather hangs.</td></tr>  <tr><td width="15" height="30" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="border-collapse:collapse" align="center"><table align="center" style="border:0;border-collapse:collapse; margin:0 auto;padding:0; border-spacing:0; background-color:#FFFFFF" cellpadding="0" cellspacing="0" border="0"><tr>
<td style="border:0;border-collapse:collapse; padding:0; border: 1px solid #000000; text-align:center; mso-padding-alt:15px 40px; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#ffffff; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb374447ff2cc22e10489f83cef867e68b1a3f0db71da3499a0606cce26a4a58a161d9ac04dd3a9312df5602382d37ceaaf56ad7d3649d45417787a" target="_blank" style="text-decoration:none; line-height:18px; text-align:center; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#000000; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;"> <span style="padding:12.5px 20.5px;display:block">SHOP THE HOODIE</span> </a></td></tr></table></td></tr> <tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr></table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1" width="100%"><tr style="display:block;"><td align="center" class="full-width-image" style="border:0;display:inline-block;padding-top:15px;padding-bottom:0px;padding-right:15px;padding-left:15px;"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444d3a61296f124c7eb3018c0e6466305febc9555654bd3281d3c4d25cf8d14782b442b0b8403a52bafa0807c7342c01d2d9610021c1ac3e07b" style="text-decoration: none"> 
<img alt="SHOP LOUNGEWEAR" class="image-desktop" src="https://images.lululemon.com/is/image/lululemon/SForce_OCT_W3_Segmented_JacktOuterwear_LoungewearSecondary_M_D" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;" width="100%"> <!--[if !mso]><!--> 
<img alt="SHOP LOUNGEWEAR" class="image-mobile" src="https://images.lululemon.com/is/image/lululemon/SForce_OCT_W3_Segmented_JacktOuterwear_LoungewearSecondary_M_M" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;display:none;" width="100%"> <!-- <![endif]--> </a></td></tr> <tr><td width="10" height="15" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> </table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border:0;border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#E1E1E1"><tr><td class="one-column" style="border:0;padding-top:0;padding-bottom:0;padding-right:15px;padding-left:15px;" bgcolor="#E1E1E1" align="center"> <!--[if true]><table width="400" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" border="0" width="400"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="border:0;margin: 0 auto; max-width: 590px; width: 100%;"><tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>  <tr>
<td style="border:0;padding:0px 31px 0px 31px;color: #000000; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 20px; line-height: 24px; text-align: center; font-weight: normal; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">When every day is a 'from-home' day, you deserve to be comfy. Our technical loungewear has four-way stretch for freedom of movement and is breathable, so you always feel good whether you're on a call, rolling out your mat, or taking it easy. </td></tr>  <tr><td width="15" height="30" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="border-collapse:collapse" align="center"><table align="center" style="border:0;border-collapse:collapse; margin:0 auto;padding:0; border-spacing:0; background-color:#FFFFFF" cellpadding="0" cellspacing="0" border="0"><tr>
<td style="border:0;border-collapse:collapse; padding:0; border: 1px solid #000000; text-align:center; mso-padding-alt:15px 40px; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#ffffff; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744476f9203c6fec6767d5ffe98bd8d7cfa9107fba44fc8d37a1179c7ec0ec68a4607e584f5854646f1f11b3355f6ab4797989bc71a75f160a37" target="_blank" style="text-decoration:none; line-height:18px; text-align:center; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#000000; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;"> <span style="padding:12.5px 20.5px;display:block">SHOP LOUNGEWEAR</span> </a></td></tr></table></td></tr> <tr><td width="30" height="40" style="border:0;font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr></table></td></tr></table><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#FFFFFF"><tr><td class="one-column" style="padding-top:0;padding-bottom:0;padding-right:15px;padding-left:15px;" align="center"><!--[if true]><table width="480" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="480"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 390px; width: 100%;"><tr><td width="30" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr>
<td style="color: #000000; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 20px; line-height: 24px; letter-spacing: 0.5px; text-align: center; font-weight: normal; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">Men's What's New</td></tr><tr><td width="15" height="30" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td class="two-column" style="padding-top:0;padding-bottom:0;padding-right:10px;padding-left:10px;text-align:center;font-size:0;"><!--[if true]><table width="600" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td width="200" align="center"> <![endif]--><div class="column full" style="width:100%;max-width:200px;display:inline-block;vertical-align:top; ">
<table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif; color:#333333;" class="full"><tr>
<td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;"><table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444d9ab759d6c03242de009dad2f784b3ce08906b907e36011a308cb231836930e4a05c19d852539813a35aa8259a0527a05c8f989116e4c4c5" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM3CH0S_046013_1" alt="Textured Tech Hoodie" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;" class="full"></a></td></tr></table></td></tr><tr>
<td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></div> <!--[if true]></td><td width="400" valign="top" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;"> <![endif]--><div class="column" style="width:100%;max-width:400px;display:inline-block;vertical-align:top;;"><table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif;color:#333333;"><tr><td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;">
<table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744476a9cb1fc360c36cd8e23fcdfd020ee8f1380ed49a780e1e16ad0f817b7737aa02495d045917a6e993ff1bcc652205dd8c7a866c3cfefc9b" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM3CPBS_8650_1" alt="Tundra Trek Vest" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;"></a></td><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center">
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb374444babec3af1b286e5477286cf503a9a521ee490f9bb14dd11e8e3b503fdfc0781b77baf8e09945f972a008e1fb4b531f779f8ed76f02e20f9" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM5ABCS_030210_1" alt="License To Train Pant" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;"></a></td></tr></table></td></tr><tr><td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></div> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td class="two-column" style="padding-top:0;padding-bottom:0;padding-right:10px;padding-left:10px; text-align:center; font-size:0;"><!--[if true]>
<table width="600" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td width="300" align="center"> <![endif]--><div class="column" style="width:100%;max-width:300px;display:inline-block;vertical-align:top;">
<table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif;color:#333333;"><tr><td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;"><table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb374448a7d0717026f49feda270d54d30e2d30296bcdcb51c4f5a5d91f2458b2cbdb651527190aa540bd8da04cd4f7d21890200bbec67dd405e8a5" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> 
<img src="https://images.lululemon.com/is/image/lululemon/LM4AADS_032894_1" alt="Down For It All Vest" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;" class="full"></a></td></tr></table></td></tr><tr><td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></div> <!--[if true]></td><td width="300" align="center"> <![endif]--><div class="column" style="width:100%;max-width:300px;display:inline-block;vertical-align:top;"><table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif;color:#333333;"><tr><td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;">
<table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744400c5c336f0faaea931d70a0d5440de7aff0e91c9ecf3e32d12b53c854e694ec10f410dc10185a586eed3f4fedd6f62f63c02b77a14c97011" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM4AAES_034270_2" alt="Down For It All Hoodie" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;" class="full"></a></td></tr></table></td></tr><tr><td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>
</table></div> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td class="two-column" style="padding-top:0;padding-bottom:0;padding-right:10px;padding-left:10px;text-align:center;font-size:0;"><!--[if true]><table width="600" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td width="400" align="center"> <![endif]--><div class="column" style="width:100%;max-width:400px;display:inline-block;vertical-align:top;">
<table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif;color:#333333;"><tr><td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;"><table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444e24e8ab2dee6295d8c5ab28e775db8c818516cb3b5a16ed97ef0256222de41a7d6d45eaefe5b30c33b4428d4336bf09463fa5e1cae1fab22" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> 
<img src="https://images.lululemon.com/is/image/lululemon/LM3CCKS_045909_1" alt="Surge Warm 1/2 Zip" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;"></a></td><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444b054d072e52f7717a05f60842a45853c563a6e523e52c276bb92e2a8b87c16cbff2f6f5e4dc6c944f0b6347d2151f85b94c971310dc8ea5f" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM3BL6S_045701_1" alt="https://shop.lululemon.com/p/men-ss-tops/Metal-Vent-Tech-Short-Sleeve-Two/_/prod140003?color=45701" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;"></a></td></tr></table></td></tr><tr>
<td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></div> <!--[if true]></td><td width="200" valign="top" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;"> <![endif]--><div class="column full" style="width:100%;max-width:200px;display:inline-block;vertical-align:top;"><table cellpadding="0" cellspacing="0" border="0" width="100%" style="border-spacing:0;font-family:sans-serif;color:#333333;" class="full"><tr><td class="inner" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;">
<table cellpadding="0" cellspacing="0" border="0" class="contents" style="border-spacing:0;font-family:sans-serif;color:#333333;width:100%;font-size:14px;text-align:center;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb3744497e6e277814dc9eaf19f330c34aa093438b06d5e5d18cc2208d4a5f0f3d8c35ddafe8082e3af8a2a03e24c15ffeb9494959e090b81f22344" style="font-size: 14px; line-height: 20px; font-weight: normal; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; color: #6e6e70; text-decoration:none;"> <img src="https://images.lululemon.com/is/image/lululemon/LM5968S_026865_1" alt="Commission Pant Classic" width="100%" style="border-width:0;width:100%;max-width:300px;height:auto; display: block;" class="full"></a></td></tr></table></td></tr><tr><td width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>
</table></div> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td width="10" height="20" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="border-collapse:collapse" align="center"></td></tr><tr><td style="border-collapse:collapse" align="center"><table align="center" style="border-collapse:collapse;margin:0 auto;padding:0;border-spacing:0;border-radius:22px;background-color:#FFFFFF" bgcolor="#FFFFFF" cellpadding="0" cellspacing="0" border="0"><tr>
<td style="border-collapse:collapse; padding:0; border: 1px solid #000000; text-align:center; mso-padding-alt:15px 40px; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 14px; color:#ffffff; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=d15457eb1fb37444950f54a5733ff215b39cec1eef5078b25918b2cf66151ce366b5a9217527febfa6a291aaaad1537b97d6d23703ffac5d222fa700e2ef5fb1" target="_blank" style="text-decoration:none; line-height:18px; text-align:center; -webkit-text-size-adjust:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; color:#000000; font-weight: bold; letter-spacing: 1.5px; text-decoration:none; text-transform: uppercase; -webkit-text-size-adjust:none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;"><!--[if !gte mso 9]><!----><span style="padding:12.5px 20.5px;display:block;"><!--<![endif]-->SEE ALL<!--[if !gte mso 9]><!----></span><!--<![endif]--> </a></td></tr></table></td></tr><tr><td width="10" height="50" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></td></tr></table><!----><!---->
<div style="display:none;">
</div>
<div style="display:none;"></div>
<table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#FFFFFF"><tr style="display:block;"><td align="center" class="full-width-image" style="display:inline-block;padding-top:0px;padding-bottom:15px;padding-right:15px;padding-left:15px;"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb374441748ca6745102579d1adb35c893e0fe367d77bb1f9d9bf61fdd159061afb3769ba4c927bc8e3b696afd14d349ac55782a46543ee9bc5e1bc" style="text-decoration: none"> 
<img alt="SHOP COATS & JACKETS" class="image-desktop" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_SingleWide_Secondary_D_Coats" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;" width="100%"> <!--[if !mso]><!--> 
<img alt="SHOP COATS & JACKETS" class="image-mobile" src="https://images.lululemon.com/is/image/lululemon/gbl_oct20_wk3_m_JandO_SingleWide_Secondary_M_Coats?cid=EM_AD_20201205_8148_PN_NW_US_MIXED_JO_MM_0_SL2_Secondary-1&utm_campaign=EM_AD_20201205_8148_PN_NW_US_MIXED_JO_MM_0_SL2&utm_source=SFMC&utm_medium=Email&riid=11735415582&mcid=4D7ACAE9-A5C0-4B8B-8B0A-60EACA9CAB54" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;display: none;" width="100%"> <!-- <![endif]--> </a></td></tr></table></td></tr></table>
<div style="display:none;"></div><!----><!---->
<div style="display:none;">
</div>
<div style="display:none;"></div>
<table cellpadding="0" cellspacing="0" width="100%" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;" bgcolor="#FFFFFF"><tr style="display:block;"><td align="center" class="full-width-image" style="display:inline-block;padding-top:0px;padding-bottom:15px;padding-right:15px;padding-left:15px;"><a href="https://click.e.lululemon.com/?qs=d15457eb1fb374442cd6125a163f2be7d30e3ff0bb55d69cca30437b05931fe2d9bcec580e4f4cde7540c185f24338ae1184ea978356f03f8c58390e74b0b7d0" style="text-decoration: none"> 
<img alt="LEARN MORE" class="image-desktop" src="https://images.lululemon.com/is/image/lululemon/NA_Oct20_IP_afterpay_email_CrossSell_Secondary_D_UPDATE2" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;" width="100%"> <!--[if !mso]><!--> 
<img alt="LEARN MORE" class="image-mobile" src="https://images.lululemon.com/is/image/lululemon/NA_Oct20_IP_afterpay_email_CrossSell_Secondary_M_UpdateIMG2?cid=EM_AD_20201205_8148_PN_NW_US_MIXED_JO_MM_0_SL2_Secondary-2&utm_campaign=EM_AD_20201205_8148_PN_NW_US_MIXED_JO_MM_0_SL2&utm_source=SFMC&utm_medium=Email&riid=11735415582&mcid=4D7ACAE9-A5C0-4B8B-8B0A-60EACA9CAB54" style="border-width:0;width:100%;max-width:620px;height:auto;font-size:30px; line-height:40px; font-family: 'Verlag-Book','HelveticaNeue-Light', arial, helvetica, sans-serif; text-align:center;font-weight:100;text-decoration:none !important;color:#333333 !important;letter-spacing:1px;text-align:center;display: none;" width="100%"> <!-- <![endif]--> </a></td></tr></table></td></tr></table>
<div style="display:none;"></div><!----><!---->
<div style="display:none;">
</div><table cellpadding="0" cellspacing="0" width="100%" role="presentation" style="min-width: 100%; " class="stylingblock-content-wrapper"><tr><td class="stylingblock-content-wrapper camarker-inner"><table class="outer" cellspacing="0" cellpadding="0" border="0" style="border-collapse:collapse; border-spacing:0; Margin:0 auto; width:100%; max-width:620px;">  <tr><td class="one-column" style="padding-top:0;padding-bottom:0;padding-right:10px;padding-left:10px;" align="center"> <!--[if true]><table width="480" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="480"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 390px; width: 100%;"><tr><td width="30" height="50" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr>
<td style="color: #000000; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-weight: 500; font-size: 20px; line-height: 24px; text-align: center; letter-spacing: 0.57px; -webkit-font-smoothing: antialiased; -moz-osx-font-smoothing: grayscale;">More to Love</td></tr><tr><td width="15" height="17" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td class="two-column mbl-mtl-padding" style="padding-top:0;padding-bottom:0;padding-right:0px;padding-left:0px; text-align:center; font-size:0;"><table align="center" border="0" cellpadding="0" cellspacing="0" class="full" width="100%"><tr><td align="center" style="vertical-align:top; font-size:0;" valign="top"> 
<!--[if true]><table width="600" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td width="300" align="center"> <![endif]--><div class="full" style="vertical-align:top; max-width:300px; width:50%; display:inline-block;"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;" class="full"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="max-width:480px; width:100%;"><tr><td class="m-padding" style="width:50%;border-collapse:collapse; padding-top: 5px; padding-right: 5px; padding-bottom: 5px; padding-left: 5px;" width="50%" align="center">
<table align="center" style="width:100%;border-collapse:collapse;margin:0 auto;padding:0;border-spacing:0; border:0;" cellpadding="0" cellspacing="0" border="0"><tr><td style="border: 1px solid #000000; text-align:center; mso-padding-alt:20px 10px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec040677a28fef4ae0c5e3801d362531bd4d25931bbab0e0a38d22e1eddad1128de4504760a10dc71bc4cdb99e607bcf1b2f24cd04500375fd1" target="_blank" style="text-decoration:none;font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 600; letter-spacing: 1.5px;text-transform: uppercase;line-height:18px;color:#000000;letter-spacing: 1.5px;"> <span style="padding:12.5px 10px;display:block"> BRAS </span> </a></td></tr></table></td>
<td class="m-padding" style="width:50%;border-collapse:collapse; padding-top: 5px; padding-right: 5px; padding-bottom: 5px; padding-left: 5px;" width="50%" align="center"><table align="center" style="width:100%;border-collapse:collapse;margin:0 auto;padding:0;border-spacing:0; border:0;" cellpadding="0" cellspacing="0" border="0"><tr><td style="border: 1px solid #000000; text-align:center; mso-padding-alt:20px 10px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0fafed165d01695b1b22b9be55ebf86693c7672d59a2068640b780fec6f6c216390f0f6a2c5f41e1ea62b0f53fbe21e434a3639f36aec121a" target="_blank" style="text-decoration:none;font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 600; letter-spacing: 1.5px;text-transform: uppercase;line-height:18px;color:#000000;letter-spacing: 1.5px;"> 
<span style="padding:12.5px 10px;display:block"> SHIRTS </span> </a></td></tr></table></td></tr></table></td></tr></table></td></tr></table></div> <!--[if mso]></td><td align="center" valign="top" style="width:300px;"> <![endif]--><div class="full" style="vertical-align:top; max-width:300px; width:50%; display:inline-block;"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;" class="full"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="max-width:480px; width:100%;"><tr>
<td class="m-padding" style="width:50%;border-collapse:collapse; padding-top: 5px; padding-right: 5px; padding-bottom: 5px; padding-left: 5px;" width="50%" align="center"><table align="center" style="width:100%;border-collapse:collapse;margin:0 auto;padding:0;border-spacing:0;" cellpadding="0" cellspacing="0" border="0"><tr><td style="border: 1px solid #000000; text-align:center; mso-padding-alt:20px 10px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec00872fabe7f708df73b51b08840a0085d74c165f3b85dbac894b9f764d387346f61a4ae5761da04464465f26d8a64246d3abc89404322a8e5" target="_blank" style="text-decoration:none;font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 600; letter-spacing: 1.5px;text-transform: uppercase;line-height:18px;color:#000000;letter-spacing: 1.5px;"> <span style="padding:12.5px 10px;display:block"> PANTS </span> 
</a></td></tr></table></td><td class="m-padding" style="width:50%;border-collapse:collapse; padding-top: 5px; padding-right: 5px; padding-bottom: 5px; padding-left: 5px;" width="50%" align="center"><table align="center" style="width:100%;border-collapse:collapse;margin:0 auto;padding:0;border-spacing:0; border:0;" cellpadding="0" cellspacing="0" border="0"><tr><td style="border: 1px solid #000000; text-align:center; mso-padding-alt:20px 10px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0be30816183a2d790b11d6d6a38e8007d7e57a513956e6b8cb7f1441abd9364106c3493ba83d10afcac12643a8c15b93d19716a225e962290" target="_blank" style="text-decoration:none;font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 600; letter-spacing: 1.5px;text-transform: uppercase;line-height:18px;color:#000000;letter-spacing: 1.5px;"> 
<span style="padding:12.5px 10px;display:block"> ACCESSORIES </span> </a></td></tr></table></td></tr></table></td></tr></table></td></tr></table></div> <!--[if (gte mso 9)|(IE)]></td></tr></table> <![endif]--></td></tr></table></td></tr>  <tr><td width="10" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> <tr><td class="two-column" style="padding-top:0;padding-bottom:0;padding-right:10px;padding-left:10px; text-align:center; font-size:0;"><table align="center" border="0" cellpadding="0" cellspacing="0" class="full" width="100%"><tr><td align="right" style="vertical-align:top; font-size:0;" valign="top"> <!--[if true]><table width="600" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td width="300" align="center"> <![endif]--><div class="full" style="vertical-align:top; max-width:310px; width:50%; display:inline-block;">
<table border="0" cellpadding="0" cellspacing="0" style="width:100%;" class="full"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;"><tr><td align="center" valign="top">
<table border="0" cellpadding="0" cellspacing="0" style="max-width:480px; width:100%;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f6339374ee252c4b51a1046a8369f6f03eec15987ec3c3b038b3b23a5ff73f6278a158339583ead1cf4fe6a40ab4ecbeb8e58eb0bc501a17" style="text-decoration:none; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; font-size: 12px; font-weight: 600; letter-spacing: 1.5px; text-transform: uppercase; color:#000000;"> <img src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/03b03b9c-38f2-4f97-82f5-463a640fc357.png" width="48" alt="" style="border-width:0;width:48px;height:auto; display: block;"> </a></td><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f8be1f0277ed1248de60f3c0d214ce4ec44bfb7a1ce17056733a456e77b423e9583aace94b353d87946e5b42a6ccc02b0bd0f255ace9100e" style="text-decoration:none; font-family: 'CalibriWeb-Regular', Helvetica, Arial, sans-serif; font-size: 12px; font-weight: 600; letter-spacing: 1.5px; text-transform: uppercase; color:#000000;"> <img src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/ce25c0d4-5415-4fd6-8452-f826ef5ee243.png" width="48" alt="" style="border-width:0;width:48px;height:auto; display: block;"> </a></td></tr><tr><td colspan="2" width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr>
<td style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; padding-top:0px;padding-bottom:0px;padding-right:0px;padding-left:0px; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" width="150"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f6339374ee252c4b51a1046a8369f6f03eec15987ec3c3b038b3b23a5ff73f6278a158339583ead1cf4fe6a40ab4ecbeb8e58eb0bc501a17" style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;">shop app</a></td>
<td style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; padding-top:0px;padding-bottom:0px;padding-right:0px;padding-left:0px; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" width="150"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0f8be1f0277ed1248de60f3c0d214ce4ec44bfb7a1ce17056733a456e77b423e9583aace94b353d87946e5b42a6ccc02b0bd0f255ace9100e" style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;">gift card</a></td></tr><tr>
<td colspan="2" width="10" height="36" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></td></tr></table></td></tr></table></div> <!--[if mso]></td><td align="center" valign="top" style="width:300px;"> <![endif]--><div class="full" style="vertical-align:top; max-width:300px;width:50%; display:inline-block;"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;" class="full"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="width:100%;"><tr><td align="center" valign="top"><table border="0" cellpadding="0" cellspacing="0" style="max-width:480px; width:100%;"><tr><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec07f9c269f04fdf12bad1761420d71490390527334f797d2223a7936a3f57fb774b75c769f3075c9e57bbd3ad77e753e0545ef44c420e8be0e" style="text-decoration:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 12px; font-weight: 600; letter-spacing: 1.5px; text-transform: uppercase; color:#000000;"> <img src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/063f90ae-4305-4d2a-b132-1658cd625f5d.png" width="48" alt="" style="border-width:0;width:48px;height:auto; display: block;"> </a></td><td style="padding-top:0;padding-bottom:0;padding-right:5px;padding-left:5px;" align="center"> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec08942b7954a4840dd66865088337afdfeb8d1c09b07c3df52fffbbc2a8337b88dc2abdf748264b6a49c2a275140193a5a6f88a03308f62aa6" style="text-decoration:none; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 12px; font-weight: 600; letter-spacing: 1.5px; text-transform: uppercase; color:#000000;"> <img src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/ad9b9d3b-9d14-4a2e-8ead-09f1f0c0faa6.png" width="48" alt="" style="border-width:0;width:48px;height:auto; display: block;"> </a></td></tr><tr><td colspan="2" width="10" height="10" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr>
<td style="color: #57585B; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; padding-top:0px;padding-bottom:0px;padding-right:0px;padding-left:0px; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" width="150"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec07f9c269f04fdf12bad1761420d71490390527334f797d2223a7936a3f57fb774b75c769f3075c9e57bbd3ad77e753e0545ef44c420e8be0e" style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;">free shipping</a></td>
<td style="color: #57585B; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; padding-top:0px;padding-bottom:0px;padding-right:0px;padding-left:0px; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" width="150"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec08942b7954a4840dd66865088337afdfeb8d1c09b07c3df52fffbbc2a8337b88dc2abdf748264b6a49c2a275140193a5a6f88a03308f62aa6" style="color: #57585B; font-family: 'CalibreWeb-Semibold', Helvetica, Arial, sans-serif; font-size: 14px; line-height: 17px; letter-spacing: 1.5px; text-transform: uppercase; text-align: center; font-weight: 600; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;">free returns</a></td></tr><tr>
<td colspan="2" width="10" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr></table></td></tr></table></td></tr></table></div> <!--[if (gte mso 9)|(IE)]></td></tr></table> <![endif]--></td></tr></table></td></tr> <tr><td class="one-column" style="padding-top:0;padding-bottom:0;padding-right:0;padding-left:0;" bgcolor="#F7F7F7" align="center"><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" width="100%"><tr><td width="10" height="40" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td align="center"> <!--[if true]><table width="300" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="300"> <![endif]--><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 285px; width: 100%;"><tr><td align="center" valign="middle"> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b45082c29657a02302790e557a6a2964ffae286ce9e08acf012af4954622d9879390e671c9e6c4e9c0bc7e404744de653888947af6041c17" style="display:block; border:0; outline:0; color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 500; letter-spacing: 1.5px; line-height:17px; text-decoration: none; text-align: center; text-transform: uppercase;" title="" align="center">SHOP WOMEN</a></td><td align="center" style="font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size:16px;letter-spacing: 1.71px;line-height:19px;text-decoration:none;color:#dfdfdf ;width:0px; text-align:center;color: #57585B">|</td><td align="center" valign="middle"> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0e382d16ee7add8866c53ef9ccbcbd77654a961c5ff5c4fe10f2887ef41389446b51a4eafad89773385d57155fd91bb58a31ea0785e05ba25" style="display:block; border:0; outline:0; color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 14px;font-weight: 500; letter-spacing: 1.5px; line-height:17px; text-decoration: none; text-align: center; text-transform: uppercase;" title="" align="center">&nbsp;SHOP MEN&nbsp;</a></td></tr></table> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td width="10" height="20" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td align="center" style="padding: 0 10px;"> <!--[if true]><table width="270" align="center" cellpadding="0" cellspacing="0" border="0"><tr><td align="center" width="270"> <![endif]-->
<table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" style="margin: 0 auto; max-width: 270px; width: 100%;"><tr><td align="center"></a> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec09acc67e29ecee148d8c6f364e7633e7e6ec3962a1cb6f41971d6ef80c3b3585bf865af88b13c1cda875a3c7f3b76dea1a723a8389aee96ee" style="text-decoration:none;mso-line-height-rule:exactly;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;width:50; vertical-align: middle; display: block;">  <img alt="Twitter" border="0" src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/8c2bd473-bab8-4314-8ca6-65c3ca3f6949.png" style="display:block; border:0; outline:0; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size:14px; color:#57585B; width:24px; min-width:24px;" title="Twitter" width="24"> </a></td><td align="center"></a> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec03cfda6baba82fb86950c0fa5e3a5bdf2cb3bbd21486d0cce3a38c045d2b27b1966c3804af9a0d87cc5c581d06138a8cf4f92786531e97210" style="text-decoration:none;mso-line-height-rule:exactly;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;width:50; vertical-align: middle; display: block;">  <img alt="Instagram" border="0" src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/58de8499-72e6-4e18-a99c-2716e957e5fe.png" style="display:block; border:0; outline:0; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size:14px; color:#57585B; width:24px; min-width:24px;" title="Instagram" width="24"> </a></td><td align="center"> </a> 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0fadd6306c10d3f0aeac9285afe86b29eacf7c598ab553ab84ce1cd239ba4c562fb33e8ae2c276c7ca74eb5f840c3d84163e44bbf0e4eee9f" style="text-decoration:none;mso-line-height-rule:exactly;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%;width:50; vertical-align: middle; display: block;">  <img alt="Facebook" border="0" src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/ad7e21df-c4b5-4faa-9957-0999abd44d24.png" style="display:block; border:0; outline:0; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size:14px; color:#57585B; width:24px; min-width:24px;" title="Facebook" width="24"> </a></td><td align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0944de42f67e76c2d60170eeff255dbfcea8c910e790b61342ed3ab0b8c4cd6686129515209101422f71c55d4edd4e9c3ad256f3cea0ad62b" target="_blank"> 
<img alt="Youtube" border="0" src="https://image.e.lululemon.com/lib/fe38117171640478741675/m/1/bf5a9aec-dc9c-4002-b604-992c18fe82f5.png" style="display:block; border:0; outline:0; font-family: 'CalibreWeb-Regular', Helvetica, Arial, sans-serif; font-size:14px; color:#57585B; width:24px; min-width:24px;" title="You Tube" width="24"> </a></td></tr>
</table> <!--[if true]></td></tr></table> <![endif]--></td></tr><tr><td align="center" width="100%"><table align="center" border="0" cellpadding="0" cellspacing="0" role="presentation" width="100%"><tr><td width="10" height="15" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="color:#57585B; font-size:10px; letter-spacing: 0.5px;line-height:14px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; text-decoration: none;font-weight: 500;" align="center">Question? <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0523fcff525ec7a2967d8aa4a1ac6b41d27c9ef90f4820ca98d4b5da99f8f0eb9ac13193631178e1023775aec1182226b70456f5d2e5c0f5d" style="color:#57585B; font-size:10px; letter-spacing: 0.5px;line-height:14px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; text-decoration: none; font-weight: 500;"> <strong>Contact us.
</strong> </a> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec06802e8cf75155be1a367c276caa77d0b609012357da429a6ed0c1f2d4b988661d47991a3610e8dea273803d5bce5f50a0039576966a50de6" style="color:#57585B; font-size:10px; letter-spacing: 0.5px;line-height:14px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; text-decoration: none; font-weight: 500;"> <strong>Privacy</strong> </a> | <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec06f4aaa0f469e9ef54d506880ff26aec7ecc40d9dfc66b51b9ce3dd99c089e3dfd024c7854e529ca291e8cd4e2e7a7d986955468289eb9c11" style="color:#57585B; font-size:10px; letter-spacing: 0.5px;line-height:14px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; text-decoration: none; font-weight: 500;"> <strong>Terms</strong> </a> | 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0450ccb3a40027a75ab5f4ad39a50f0ebe28731a0e516c0880f3db545b61b3c4413bb1d3eb5d8301d8a3472bcdde3eaa69b92f7b69c92cbe9" style="color:#57585B; font-size:10px; letter-spacing: 0.5px;line-height:14px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; text-decoration: none; font-weight: 500;"> <strong>Careers</strong> </a></td></tr><tr><td width="10" height="12" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> <tr><td style="color: #57585B; letter-spacing: 0.5px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; line-height:14px; text-align: center;font-weight: 500;" align="center">View in&nbsp; 
<a href="https://view.e.lululemon.com/?qs=80ac8e571ad5621ceddf3f228936185173dd29d3ed241b6acf8267bb8230acec690d3b684d35abf616e8d1219db98301343198d07dbdbb9e06d4b2dbf5c3139ee85cbfce93cabfb0" style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; text-align: center; font-weight: 500; letter-spacing: 0.5px;text-decoration: none;"> <strong>web browser</strong> </a></td></tr><tr><td width="10" height="12" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr> <tr><td style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; line-height:14px; text-align: center; font-weight: 500; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale; padding-left: 20px; padding-right: 20px; letter-spacing: 0.5px;" align="center"> This  
<img alt="" border="0" width="15" src="https://images.lululemon.com/is/image/lululemon/us-region2" style="border:0;height:auto;width:15px;outline:none;text-decoration:none;-ms-interpolation-mode:bicubic;"> version of the email was sent to <a href="mailto:ansarb24@gmail.com" style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; text-align: center; font-weight: 500; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;letter-spacing: 0.5px;"> <strong>ansarb24@gmail.com</strong> 
</a> <br> Make sure this email goes to your inbox. Add <a href="mailto:hello@e.lululemon.com" style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; text-align: center; font-weight: 500; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;letter-spacing: 0.5px;line-height:14px;"> <strong>hello@e.lululemon.com</strong> </a> to your address book. <br> Already in the loop? 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b2de9d74b15563ffed35c9ce74f4c432ebda7bbac613daf52d1084c267598b94ea60eecdb7caa1c311a8fd242404b8fa1d4add5aef5ab62d" style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; text-align: center; font-weight: 500; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;letter-spacing: 0.5px;line-height:14px;"  target="_blank"> <strong>Manage Preferences</strong> </a> or 
<a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec0b2de9d74b15563ffed35c9ce74f4c432ebda7bbac613daf52d1084c267598b94ea60eecdb7caa1c311a8fd242404b8fa1d4add5aef5ab62d" style="color: #57585B; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; font-size: 10px; text-align: center; font-weight: 500; text-decoration: none; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;letter-spacing: 0.5px;line-height:14px;"  target="_blank"> <strong>Unsubscribe</strong> </a></td></tr><tr>
<td width="10" height="30" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr><tr><td style="text-transform:uppercase;color:#57585B !important; font-size:10px; letter-spacing: 1px; line-height:14px;; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec057f800f491f205c2a85c75512458ad539cb95ed383041571bc0e08748a07838719f226d72ad2b5df1898868e8c060c9dd58f6100a6a69bb8" style="text-decoration:none !important; color:#57585B !important; font-size:10px; font-weight: 500; letter-spacing: 1px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" target="_blank"> <span>&copy; 2020 LULULEMON ATHLETICA</span> </a></td></tr><tr>
<td style="text-transform:uppercase;color:#57585B !important; font-size:10px; letter-spacing: 1px; line-height:14px;; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; padding-bottom:10px;" align="center"> <a href="https://click.e.lululemon.com/?qs=e4bf069a63a56ec057f800f491f205c2a85c75512458ad539cb95ed383041571bc0e08748a07838719f226d72ad2b5df1898868e8c060c9dd58f6100a6a69bb8" style="text-decoration:none !important; color:#57585B !important; font-size:10px; font-weight: 500; letter-spacing: 1px; font-family: 'CalibreWeb-Medium', Helvetica, Arial, sans-serif; -webkit-font-smoothing: antialiased;-moz-osx-font-smoothing: grayscale;" target="_blank"> <span>1818 CORNWALL AVENUE, VANCOUVER BC, V6J 1C7</span> </a></td></tr><tr><td width="10" height="50" style="font-size:1px; line-height:1px; mso-line-height-rule: exactly;">&nbsp;</td></tr>
</table></td></tr></table></td></tr></table></td></tr></table><!---->
              
                                                </td>
                                              </tr>
                                              </tbody>
                                            </table>
                                          </td>
                                        </tr>
                                    </tbody>
                                  </table>
                                </td>
                              </tr>
                            </table>
                          </td>
                        </tr>
                      </table>
                    </td>
                  </tr>
                </table>
              </td>
            </tr>
          </table>
        </td>
      </tr>
      <tr>
        <td valign="top">
          
        </td>
      </tr>
    </table>
    <!-- 250OK -->
    <style> @media print{ #_two50 { background-image:url('http://analytics.lululemon.com/ea/jGylPIc2rE/?t=p&e=ansarb24@gmail.com&c=AD_20201021_PN_NW_US_MM_SL2'); } } blockquote #_two50, #mailContainerBody #_two50, div.OutlookMessageHeader, table.moz-email-headers-table { background-image:url('http://analytics.lululemon.com/ea/jGylPIc2rE/?t=f&e=ansarb24@gmail.com&c=AD_20201021_PN_NW_US_MM_SL2'); } </style> <div id='_two50'></div> <img id='_two50_img' src='http://analytics.lululemon.com/ea/jGylPIc2rE/?e=ansarb24@gmail.com&c=AD_20201021_PN_NW_US_MM_SL2' alt= "" width='1' height='1' style='margin:0 !important; padding:0 !important; border:0 !important; height:1px !important; width:1px !important;' />
    <div class="gmailfix" style="white-space:nowrap; font:15px courier; line-height:0;">
&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 
&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 
&nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;
</div>
  </body>
</html>

"""

# %% [markdown]
# ### 5. Final Prep and Send email

# %%
host = "smtp.gmail.com"
port = 587
username = "devapppk@gmail.com"
password= "**************"
from_email = "lululemon <hello@e.lululemon.com>"
email_conn = smtplib.SMTP(host,port)
email_conn.ehlo()
email_conn.starttls()
email_conn.login(username,password)
start_time1 = time.time()
#Login part End#
#-----Load Emails and Names from Excel Sheet and loop-----#
wb = xl.load_workbook(r"D:\Upwork\PuBulkEmailSender\EmailList.xlsx")
sheet1 = wb[('Sheet1')]
names = []
emails = []
for cell in sheet1['A']:
    emails.append(cell.value)
for cell in sheet1['B']:
    names.append(cell.value)
for i in range(len(emails)):
    elapsed_time = time.time() - start_time1
    the_msg = MIMEMultipart("alternative")
    the_msg['Subject'] = "Inquiry - {} ".format(names[i])
    the_msg['From'] = "lululemon <hello@e.lululemon.com>"
    the_msg['To'] = emails[i]
    the_msg['Reply-To'] = "lululemon <hello@e.lululemon.com>"
    part_1 = MIMEText(plain_txt,'plain')
    part_2 = MIMEText(html_txt,'html')
    the_msg.attach(part_1)
    the_msg.attach(part_2)
    the_msg.add_header('List-Unsubscribe', '<unsubscribe@lululemon.com>')
    email_conn.sendmail(from_email,emails[i],the_msg.as_string())
    t1='Time Spent '+ time.strftime("%H:%M:%S", time.gmtime(elapsed_time))
    print(colored('Email sent to ', 'white'), colored(emails[i], 'green'),colored(t1, 'white'))
    sleep(randint(3,8))
    elapsed_time1 = time.time() - start_time
email_conn.quit()
print("All Emails Sent - Total Time Spent", time.strftime("%H:%M:%S", time.gmtime(elapsed_time1)))
# Out:
# Email sent to  ahmed.onw@gmail.com Time Spent 00:00:00
# Email sent to  m.iaj@outlook.com Time Spent 00:00:11
# Email sent to  dtsng2020@gmail.com Time Spent 00:00:16
# Email sent to  salmanjamil433@gmail.com Time Spent 00:00:21
# Email sent to  abubakar.nrw@gmail.com Time Spent 00:00:29
# All Emails Sent - Total Time Spent 00:00:41
